# %% [markdown]
# #1 - Introduction

# %% [markdown]
# This notebook presents the Teaching-Learning-Based Optimization (TLBO) algorithm, a metaheuristic optimization technique inspired by the teaching process in a classroom.

# %% [markdown]
# #2 - Setup and Imports

# %% [markdown]
# ### 2.1 - import the necessary libraries

# %%
# import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2.2 - Define problem parameters

# %%
# Define problem parameters
lower_bound = -5  # Lower bound of the search space.
upper_bound = 5   # Upper bound of the search space.

num_variables = 4    # Number of decision variables.
population_size = 5  # Size of the population.

TF = 2  # Teaching factor

num_iterations = 1000      # Number of iterations.
threshold_fitness = 0.01  # Threshold fitness value.

# %% [markdown]
# ### 2.3 - Optimization Function Definition

# %%
# Define the optimization function
def optimization_function(x1, x2, x3, x4):
    """Objective function."""
    return x1**2 + x2**2 + x3**2 + x4**2

# %% [markdown]
# #3 - TLBO Utility Functions

# %% [markdown]
# ### 3.1 - Initialization Function

# %%
def initialize_population(population_size, lower_bound, upper_bound, num_variables):
    population = []
    for _ in range(population_size):
        individual = np.random.uniform(lower_bound, upper_bound, num_variables)  # Generating a random individual within the specified bounds.
        population.append(individual)
    return population

# %% [markdown]
# ### 3.2 - Teaching Phase

# %%
def teaching_phase(population, fitness_values):
    best_index = np.argmin(fitness_values)    # Finding the index of the individual with the best fitness.
    teacher = population[best_index]          # Selecting the best individual as the teacher.
    mean_value = np.mean(population, axis=0)  # Calculating the mean of all individuals in the population.

    # Performing teaching phase operation.
    for i, individual in enumerate(population):
        ri = np.random.uniform(0, 1, size=len(teacher))
        new_individual = individual + ri * (teacher - TF * mean_value)

        # Boundary check
        new_individual = np.clip(new_individual, lower_bound, upper_bound)

        # Updating individual in population with new value.
        population[i] = new_individual

     # Calculating fitness values for the updated population.
    fitness_values = [optimization_function(*individual) for individual in population]

    return population

# %% [markdown]
# ### 3.3 - Learning Phase

# %%
def learning_phase(population, fitness_values):
    partner_indices = np.random.choice(len(population), size=len(population), replace=True)

    for i, individual in enumerate(population):
        partner_index = partner_indices[i]
        partner = population[partner_index]
        ri = np.random.uniform(0, 1, size=len(individual))

        if fitness_values[i] < fitness_values[partner_index]:
            new_individual = individual + ri * (partner - individual)  # Performing learning phase operation if individual is better.
        else:
            new_individual = individual - ri * (partner - individual)  # Performing learning phase operation if partner is better.

        # Boundary check
        new_individual = np.clip(new_individual, lower_bound, upper_bound)
        # Updating individual in population with new value.
        population[i] = new_individual

    # Calculating fitness values for the updated population.
    fitness_values = [optimization_function(*individual) for individual in population]

    return population

# %% [markdown]
# ### 3.4 - Population points

# %%
def print_population_info(population, fitness_values, iteration=None):
    # Iterating through each individual in the population and printing their rounded values and fitness.
    for i, individual in enumerate(population):
        rounded_ind = np.round(individual, 2)
        print(f"Individual {i+1}: {rounded_ind}\t Fitness: {fitness_values[i]:.2f}")

# %% [markdown]
# ### 3.5 - Final Best point

# %%
def final_result(fitness_values, population):
    # Finding the minimum fitness value in the fitness_values list.
    min_fitness = min(fitness_values)
    # Finding the index of the minimum fitness value in the fitness_values list.
    min_index = fitness_values.index(min_fitness)
    # Retrieving the solution corresponding to the minimum fitness value.
    min_solution = population[min_index]
    # Rounding the minimum solution values for neatness.
    rounded_min_solution = np.round(min_solution, 2)
    # Printing the minimum solution and its fitness value.
    print(f"\nMinimum Solution: {rounded_min_solution}\t Fitness: {min_fitness:.2f}")

    # Printing a separator.
    print("\n","=" * 65)

# %% [markdown]
# # 4 - Iteration Function

# %%
def tlbo_iteration(population, fitness_values, iteration):
    print(f"\nIteration {iteration}:")
    print('-'*15)

    # Printing information about each individual in the population.
    print_population_info(population, fitness_values)

    print('-'*65)
    teacher_index = np.argmin(fitness_values)
    teacher_fitness = fitness_values[teacher_index]
    rounded_teacher_index = np.round(population[teacher_index], 2)
    print(f"Teacher: {rounded_teacher_index}\t Fitness: {teacher_fitness:.2f}")

    print('-'*65)
    population_mean = np.mean(population, axis=0)
    rounded_mean_value = np.round(population_mean, 2)
    print(f"Population Mean: {rounded_mean_value}")

    print('-'*65)
    population = teaching_phase(population, fitness_values)
    print("[1] The Population After Teaching Phase:")
    print('-'*40)
    print_population_info(population, fitness_values)

    print('-'*65)
    partner_index = np.random.randint(len(population))
    rounded_partner_index = np.round(population[partner_index], 2)
    print(f"Partner: {rounded_partner_index}")

    print('-'*65)
    population = learning_phase(population, fitness_values)
    print("[2] The Population After Learning Phase:")
    print('-'*40)
    print_population_info(population, fitness_values)
    print("\n","=" * 65)

    return population

# %% [markdown]
# #5 - Main Function

# %%
def main():
    # Initialize population
    population = initialize_population(population_size, lower_bound, upper_bound, num_variables)

    # Track fitness values for each individual in the population
    fitness_values = [optimization_function(*individual) for individual in population]

    # Track best solution and its fitness value
    best_fitness = min(fitness_values)
    best_solution = population[np.argmin(fitness_values)]

    # Track convergence
    convergence = [best_fitness]

    # Perform TLBO iterations with a maximum limit and convergence criterion
    iteration = 0
    while iteration < num_iterations:  # Maximum number of iterations
        # Teaching and Learning phases
        population = tlbo_iteration(population, fitness_values, iteration + 1)

        # Update fitness values
        fitness_values = [optimization_function(*individual) for individual in population]

        # Check convergence criterion
        new_best_fitness = min(fitness_values)
        if abs(new_best_fitness - best_fitness) < threshold_fitness:
            break  # Exit loop if convergence criterion is met
        else:
            best_fitness = new_best_fitness
            convergence.append(best_fitness)

        iteration += 1

    # Print final results
    final_result(fitness_values, population)

# %%
if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# Individual 4: [-2.48 -2.91  0.24 -4.47]	 Fitness: 28.97
# Individual 5: [-0.22  1.12  3.66  1.98]	 Fitness: 49.92
#
#  =================================================================
#
# Iteration 778:
# ---------------
# Individual 1: [-2.53 -3.4  -5.   -5.  ]	 Fitness: 67.95
# Individual 2: [ 5.    5.    2.27 -4.01]	 Fitness: 71.19
# Individual 3: [-3.08  5.   -3.97 -2.58]	 Fitness: 56.87
# Individual 4: [-2.48 -2.91  0.24 -4.47]	 Fitness: 34.68
# Individual 5: [-0.22  1.12  3.66  1.98]	 Fitness: 18.65
# -----------------------------------------------------------------
# Teacher: [-0.22  1.12  3.66  1.98]	 Fitness: 18.65
# -----------------------------------------------------------------
# Population Mean: [-0.66  0.96 -0.56 -2.82]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-2.48 -3.55 -2.72 -1.88]	 Fitness: 67.95
# Individual 2: [ 5.    4.53  4.14 -1.79]	 Fitness: 71.19
# Individual 3: [-2.32  4.24 -3.21 -1.88]	 Fitness: 56.87
# Individual 4: [-2.09 -3.52  1.4  -3.45]	 Fitness: 34.68
# Individual 5: [0.55 1.   4.77 5.  ]	 Fitness: 18.65
# -----------------------------------------------------------------
# Partner: [-2.48 -3.55 -2.72 -1.88]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5.   -4.98 -5.   -5.  ]	 Fitness: 67.95
# Individual 2: [ 5.    5.    5.   -1.51]	 Fitness: 71.19
# Individual 3: [-2.7   5.   -3.75 -4.18]	 Fitness: 56.87
# Individual 4: [-2.09 -3.52  1.4  -3.45]	 Fitness: 34.68
# Individual 5: [4.5  4.67 4.84 3.49]	 Fitness: 18.65
#
#  =================================================================
#
# Iteration 779:
# ---------------
# Individual 1: [-5.   -4.98 -5.   -5.  ]	 Fitness: 99.82
# Individual 2: [ 5.    5.    5.   -1.51]	 Fitness: 77.29
# Individual 3: [-2.7   5.   -3.75 -4.18]	 Fitness: 63.84
# Individual 4: [-2.09 -3.52  1.4  -3.45]	 Fitness: 30.60
# Individual 5: [4.5  4.67 4.84 3.49]	 Fitness: 77.70
# -----------------------------------------------------------------
# Teacher: [-2.09 -3.52  1.4  -3.45]	 Fitness: 30.60
# -----------------------------------------------------------------
# Population Mean: [-0.06  1.23  0.5  -2.13]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-5.   -5.   -4.67 -4.73]	 Fitness: 99.82
# Individual 2: [ 4.17  0.36  5.   -1.27]	 Fitness: 77.29
# Individual 3: [-3.43  3.51 -3.36 -3.6 ]	 Fitness: 63.84
# Individual 4: [-3.79 -5.    1.72 -3.31]	 Fitness: 30.60
# Individual 5: [4.23 0.38 5.   3.52]	 Fitness: 77.70
# -----------------------------------------------------------------
# Partner: [4.23 0.38 5.   3.52]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 99.82
# Individual 2: [-4.03 -2.62  2.31 -3.54]	 Fitness: 77.29
# Individual 3: [-3.09  5.   -5.   -3.6 ]	 Fitness: 63.84
# Individual 4: [-3.79 -3.03  1.9  -3.32]	 Fitness: 30.60
# Individual 5: [4.23 0.38 5.   3.52]	 Fitness: 77.70
#
#  =================================================================
#
# Iteration 780:
# ---------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [-4.03 -2.62  2.31 -3.54]	 Fitness: 40.98
# Individual 3: [-3.09  5.   -5.   -3.6 ]	 Fitness: 72.56
# Individual 4: [-3.79 -3.03  1.9  -3.32]	 Fitness: 38.16
# Individual 5: [4.23 0.38 5.   3.52]	 Fitness: 55.39
# -----------------------------------------------------------------
# Teacher: [-3.79 -3.03  1.9  -3.32]	 Fitness: 38.16
# -----------------------------------------------------------------
# Population Mean: [-2.34 -1.05 -0.16 -2.39]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-4.47 -5.   -4.08 -4.65]	 Fitness: 100.00
# Individual 2: [-3.73 -2.7   2.59 -2.59]	 Fitness: 40.98
# Individual 3: [-2.37  4.23 -3.15 -3.31]	 Fitness: 72.56
# Individual 4: [-3.19 -3.65  3.99 -2.9 ]	 Fitness: 38.16
# Individual 5: [ 4.5  -0.44  5.    4.18]	 Fitness: 55.39
# -----------------------------------------------------------------
# Partner: [-3.73 -2.7   2.59 -2.59]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-4.47 -5.   -4.08 -4.65]	 Fitness: 100.00
# Individual 2: [-3.93 -2.62  1.98 -2.48]	 Fitness: 40.98
# Individual 3: [-2.37  4.23 -3.15 -3.31]	 Fitness: 72.56
# Individual 4: [ 2.01 -2.64  4.34 -2.77]	 Fitness: 38.16
# Individual 5: [ 5.  -0.4  5.   5. ]	 Fitness: 55.39
#
#  =================================================================
#
# Iteration 781:
# ---------------
# Individual 1: [-4.47 -5.   -4.08 -4.65]	 Fitness: 83.22
# Individual 2: [-3.93 -2.62  1.98 -2.48]	 Fitness: 32.38
# Individual 3: [-2.37  4.23 -3.15 -3.31]	 Fitness: 44.40
# Individual 4: [ 2.01 -2.64  4.34 -2.77]	 Fitness: 37.45
# Individual 5: [ 5.  -0.4  5.   5. ]	 Fitness: 75.16
# -----------------------------------------------------------------
# Teacher: [-3.93 -2.62  1.98 -2.48]	 Fitness: 32.38
# -----------------------------------------------------------------
# Population Mean: [-0.75 -1.29  0.82 -1.64]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-5.   -5.   -3.97 -3.9 ]	 Fitness: 83.22
# Individual 2: [-4.7  -2.66  2.15 -1.79]	 Fitness: 32.38
# Individual 3: [-2.39  4.2  -2.87 -3.13]	 Fitness: 44.40
# Individual 4: [ 0.05 -2.69  4.47 -2.13]	 Fitness: 37.45
# Individual 5: [ 2.93 -0.43  5.    5.  ]	 Fitness: 75.16
# -----------------------------------------------------------------
# Partner: [-5.   -5.   -3.97 -3.9 ]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5.   -5.   -4.79 -4.23]	 Fitness: 83.22
# Individual 2: [-1.06 -0.77  3.42 -0.46]	 Fitness: 32.38
# Individual 3: [-2.39  4.2  -2.87 -3.13]	 Fitness: 44.40
# Individual 4: [-4.78 -4.76 -4.74 -3.49]	 Fitness: 37.45
# Individual 5: [ 2.93 -0.43  5.    5.  ]	 Fitness: 75.16
#
#  =================================================================
#
# Iteration 782:
# ---------------
# Individual 1: [-5.   -5.   -4.79 -4.23]	 Fitness: 90.91
# Individual 2: [-1.06 -0.77  3.42 -0.46]	 Fitness: 13.63
# Individual 3: [-2.39  4.2  -2.87 -3.13]	 Fitness: 41.45
# Individual 4: [-4.78 -4.76 -4.74 -3.49]	 Fitness: 80.14
# Individual 5: [ 2.93 -0.43  5.    5.  ]	 Fitness: 58.76
# -----------------------------------------------------------------
# Teacher: [-1.06 -0.77  3.42 -0.46]	 Fitness: 13.63
# -----------------------------------------------------------------
# Population Mean: [-2.06 -1.35 -0.8  -1.26]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-3.55 -3.62 -1.55 -2.54]	 Fitness: 90.91
# Individual 2: [ 1.45 -0.36  5.   -0.29]	 Fitness: 13.63
# Individual 3: [-0.61  4.91  0.37 -1.84]	 Fitness: 41.45
# Individual 4: [-4.6  -3.71 -0.9  -2.98]	 Fitness: 80.14
# Individual 5: [3.76 1.41 5.   5.  ]	 Fitness: 58.76
# -----------------------------------------------------------------
# Partner: [-0.61  4.91  0.37 -1.84]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-2.74 -3.59 -2.18 -2.19]	 Fitness: 90.91
# Individual 2: [-0.38 -3.65  1.17 -1.4 ]	 Fitness: 13.63
# Individual 3: [3.23 4.11 4.56 0.64]	 Fitness: 41.45
# Individual 4: [-5.   -3.76 -1.9  -4.35]	 Fitness: 80.14
# Individual 5: [4.67 3.37 5.   5.  ]	 Fitness: 58.76
#
#  =================================================================
#
# Iteration 783:
# ---------------
# Individual 1: [-2.74 -3.59 -2.18 -2.19]	 Fitness: 29.99
# Individual 2: [-0.38 -3.65  1.17 -1.4 ]	 Fitness: 16.80
# Individual 3: [3.23 4.11 4.56 0.64]	 Fitness: 48.51
# Individual 4: [-5.   -3.76 -1.9  -4.35]	 Fitness: 61.69
# Individual 5: [4.67 3.37 5.   5.  ]	 Fitness: 83.12
# -----------------------------------------------------------------
# Teacher: [-0.38 -3.65  1.17 -1.4 ]	 Fitness: 16.80
# -----------------------------------------------------------------
# Population Mean: [-0.05 -0.7   1.33 -0.46]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-2.85 -4.96 -3.66 -2.29]	 Fitness: 29.99
# Individual 2: [-0.65 -4.13  0.98 -1.83]	 Fitness: 16.80
# Individual 3: [3.15 2.55 4.54 0.21]	 Fitness: 48.51
# Individual 4: [-5.   -3.9  -2.39 -4.83]	 Fitness: 61.69
# Individual 5: [4.38 2.47 3.73 4.63]	 Fitness: 83.12
# -----------------------------------------------------------------
# Partner: [-2.85 -4.96 -3.66 -2.29]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-4.68 -5.   -5.   -2.29]	 Fitness: 29.99
# Individual 2: [0.1  2.33 1.53 4.08]	 Fitness: 16.80
# Individual 3: [ 5.    2.77  5.   -0.86]	 Fitness: 48.51
# Individual 4: [-1.89 -0.44  1.44 -4.69]	 Fitness: 61.69
# Individual 5: [5.   4.91 5.   5.  ]	 Fitness: 83.12
#
#  =================================================================
#
# Iteration 784:
# ---------------
# Individual 1: [-4.68 -5.   -5.   -2.29]	 Fitness: 77.15
# Individual 2: [0.1  2.33 1.53 4.08]	 Fitness: 24.44
# Individual 3: [ 5.    2.77  5.   -0.86]	 Fitness: 58.42
# Individual 4: [-1.89 -0.44  1.44 -4.69]	 Fitness: 27.83
# Individual 5: [5.   4.91 5.   5.  ]	 Fitness: 99.03
# -----------------------------------------------------------------
# Teacher: [0.1  2.33 1.53 4.08]	 Fitness: 24.44
# -----------------------------------------------------------------
# Population Mean: [0.71 0.91 1.59 0.25]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-4.77 -4.64 -5.   -0.9 ]	 Fitness: 77.15
# Individual 2: [-0.91  2.68  0.45  4.81]	 Fitness: 24.44
# Individual 3: [4.61 3.16 3.73 2.72]	 Fitness: 58.42
# Individual 4: [-2.03 -0.38  1.43 -3.53]	 Fitness: 27.83
# Individual 5: [4.44 4.91 3.95 5.  ]	 Fitness: 99.03
# -----------------------------------------------------------------
# Partner: [-0.91  2.68  0.45  4.81]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 77.15
# Individual 2: [3.79 3.4  0.65 4.93]	 Fitness: 24.44
# Individual 3: [5.   3.74 5.   5.  ]	 Fitness: 58.42
# Individual 4: [-5.   -3.16  1.89 -5.  ]	 Fitness: 27.83
# Individual 5: [4.44 4.91 3.95 5.  ]	 Fitness: 99.03
#
#  =================================================================
#
# Iteration 785:
# ---------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [3.79 3.4  0.65 4.93]	 Fitness: 50.71
# Individual 3: [5.   3.74 5.   5.  ]	 Fitness: 89.02
# Individual 4: [-5.   -3.16  1.89 -5.  ]	 Fitness: 63.57
# Individual 5: [4.44 4.91 3.95 5.  ]	 Fitness: 84.45
# -----------------------------------------------------------------
# Teacher: [3.79 3.4  0.65 4.93]	 Fitness: 50.71
# -----------------------------------------------------------------
# Population Mean: [0.65 0.78 1.3  0.99]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-2.64 -4.35 -5.   -3.47]	 Fitness: 100.00
# Individual 2: [ 5.    4.84 -0.71  5.  ]	 Fitness: 50.71
# Individual 3: [5.   3.86 4.29 5.  ]	 Fitness: 89.02
# Individual 4: [-3.57 -2.02  0.1  -3.46]	 Fitness: 63.57
# Individual 5: [4.59 5.   2.86 5.  ]	 Fitness: 84.45
# -----------------------------------------------------------------
# Partner: [-2.64 -4.35 -5.   -3.47]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [4.67 4.86 0.66 5.  ]	 Fitness: 50.71
# Individual 3: [-4.48 -2.03 -0.95  2.8 ]	 Fitness: 89.02
# Individual 4: [-3.93 -2.03 -0.12  2.05]	 Fitness: 63.57
# Individual 5: [-4.8   0.63 -0.94  4.9 ]	 Fitness: 84.45
#
#  =================================================================
#
# Iteration 786:
# ---------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [4.67 4.86 0.66 5.  ]	 Fitness: 70.84
# Individual 3: [-4.48 -2.03 -0.95  2.8 ]	 Fitness: 32.89
# Individual 4: [-3.93 -2.03 -0.12  2.05]	 Fitness: 23.79
# Individual 5: [-4.8   0.63 -0.94  4.9 ]	 Fitness: 48.32
# -----------------------------------------------------------------
# Teacher: [-3.93 -2.03 -0.12  2.05]	 Fitness: 23.79
# -----------------------------------------------------------------
# Population Mean: [-2.71 -0.71 -1.27  1.95]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-4.47 -5.   -3.16 -5.  ]	 Fitness: 100.00
# Individual 2: [5.   4.47 1.86 3.71]	 Fitness: 70.84
# Individual 3: [-3.1  -2.26  0.03  1.11]	 Fitness: 32.89
# Individual 4: [-2.89 -2.1   0.4   1.63]	 Fitness: 23.79
# Individual 5: [-3.55  0.39 -0.62  3.26]	 Fitness: 48.32
# -----------------------------------------------------------------
# Partner: [-3.1  -2.26  0.03  1.11]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-4.47 -5.   -3.16 -5.  ]	 Fitness: 100.00
# Individual 2: [5.   4.47 1.86 3.71]	 Fitness: 70.84
# Individual 3: [-1.26  3.3   0.09  3.16]	 Fitness: 32.89
# Individual 4: [-2.55 -1.88  0.17  1.95]	 Fitness: 23.79
# Individual 5: [-3.55  0.39 -0.62  3.26]	 Fitness: 48.32
#
#  =================================================================
#
# Iteration 787:
# ---------------
# Individual 1: [-4.47 -5.   -3.16 -5.  ]	 Fitness: 79.98
# Individual 2: [5.   4.47 1.86 3.71]	 Fitness: 62.25
# Individual 3: [-1.26  3.3   0.09  3.16]	 Fitness: 22.51
# Individual 4: [-2.55 -1.88  0.17  1.95]	 Fitness: 13.86
# Individual 5: [-3.55  0.39 -0.62  3.26]	 Fitness: 23.74
# -----------------------------------------------------------------
# Teacher: [-2.55 -1.88  0.17  1.95]	 Fitness: 13.86
# -----------------------------------------------------------------
# Population Mean: [-1.37  0.26 -0.33  1.42]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-4.43 -5.   -2.93 -5.  ]	 Fitness: 79.98
# Individual 2: [5.   3.65 2.39 3.03]	 Fitness: 62.25
# Individual 3: [-1.22  1.24  0.65  2.51]	 Fitness: 22.51
# Individual 4: [-2.49 -4.23  0.4   1.71]	 Fitness: 13.86
# Individual 5: [-3.39 -1.93 -0.45  2.63]	 Fitness: 23.74
# -----------------------------------------------------------------
# Partner: [5.   3.65 2.39 3.03]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-4.86 -5.   -5.   -5.  ]	 Fitness: 79.98
# Individual 2: [5.   5.   3.58 3.15]	 Fitness: 62.25
# Individual 3: [-0.93  4.24  0.86  2.7 ]	 Fitness: 22.51
# Individual 4: [-2.63 -4.04  0.07  2.53]	 Fitness: 13.86
# Individual 5: [ 3.71 -1.52  2.02  2.64]	 Fitness: 23.74
#
#  =================================================================
#
# Iteration 788:
# ---------------
# Individual 1: [-4.86 -5.   -5.   -5.  ]	 Fitness: 98.59
# Individual 2: [5.   5.   3.58 3.15]	 Fitness: 72.68
# Individual 3: [-0.93  4.24  0.86  2.7 ]	 Fitness: 26.86
# Individual 4: [-2.63 -4.04  0.07  2.53]	 Fitness: 29.61
# Individual 5: [ 3.71 -1.52  2.02  2.64]	 Fitness: 27.15
# -----------------------------------------------------------------
# Teacher: [-0.93  4.24  0.86  2.7 ]	 Fitness: 26.86
# -----------------------------------------------------------------
# Population Mean: [ 0.06 -0.26  0.31  1.2 ]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-5.   -4.6  -4.78 -4.95]	 Fitness: 98.59
# Individual 2: [4.6  5.   3.64 3.38]	 Fitness: 72.68
# Individual 3: [-1.76  5.    0.91  2.78]	 Fitness: 26.86
# Individual 4: [-2.96  0.12  0.12  2.55]	 Fitness: 29.61
# Individual 5: [ 3.45 -0.28  2.26  2.71]	 Fitness: 27.15
# -----------------------------------------------------------------
# Partner: [-5.   -4.6  -4.78 -4.95]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5.   -4.6  -4.78 -4.95]	 Fitness: 98.59
# Individual 2: [5.   5.   4.96 3.57]	 Fitness: 72.68
# Individual 3: [-1.76  5.    0.91  2.78]	 Fitness: 26.86
# Individual 4: [-3.25  0.13 -1.71  2.52]	 Fitness: 29.61
# Individual 5: [-2.23 -0.12  0.49  2.56]	 Fitness: 27.15
#
#  =================================================================
#
# Iteration 789:
# ---------------
# Individual 1: [-5.   -4.6  -4.78 -4.95]	 Fitness: 93.58
# Individual 2: [5.   5.   4.96 3.57]	 Fitness: 87.33
# Individual 3: [-1.76  5.    0.91  2.78]	 Fitness: 36.66
# Individual 4: [-3.25  0.13 -1.71  2.52]	 Fitness: 19.81
# Individual 5: [-2.23 -0.12  0.49  2.56]	 Fitness: 11.76
# -----------------------------------------------------------------
# Teacher: [-2.23 -0.12  0.49  2.56]	 Fitness: 11.76
# -----------------------------------------------------------------
# Population Mean: [-1.45  1.08 -0.02  1.29]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-4.84 -5.   -4.51 -4.98]	 Fitness: 93.58
# Individual 2: [5.   4.34 5.   3.55]	 Fitness: 87.33
# Individual 3: [-1.46  4.96  1.31  2.78]	 Fitness: 36.66
# Individual 4: [-2.7  -0.46 -1.55  2.5 ]	 Fitness: 19.81
# Individual 5: [-2.16 -1.77  0.8   2.54]	 Fitness: 11.76
# -----------------------------------------------------------------
# Partner: [-2.16 -1.77  0.8   2.54]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 93.58
# Individual 2: [5.   4.34 5.   3.55]	 Fitness: 87.33
# Individual 3: [-0.87  5.    1.44  2.79]	 Fitness: 36.66
# Individual 4: [-1.88  3.69 -1.3   2.75]	 Fitness: 19.81
# Individual 5: [-2.11  0.53 -0.88  2.59]	 Fitness: 11.76
#
#  =================================================================
#
# Iteration 790:
# ---------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [5.   4.34 5.   3.55]	 Fitness: 81.39
# Individual 3: [-0.87  5.    1.44  2.79]	 Fitness: 35.63
# Individual 4: [-1.88  3.69 -1.3   2.75]	 Fitness: 26.45
# Individual 5: [-2.11  0.53 -0.88  2.59]	 Fitness: 12.23
# -----------------------------------------------------------------
# Teacher: [-2.11  0.53 -0.88  2.59]	 Fitness: 12.23
# -----------------------------------------------------------------
# Population Mean: [-0.97  1.71 -0.15  1.34]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [4.98 2.08 4.5  3.54]	 Fitness: 81.39
# Individual 3: [-1.02  2.18  1.35  2.73]	 Fitness: 35.63
# Individual 4: [-1.96  2.31 -1.82  2.74]	 Fitness: 26.45
# Individual 5: [-2.13  0.24 -1.03  2.56]	 Fitness: 12.23
# -----------------------------------------------------------------
# Partner: [-2.13  0.24 -1.03  2.56]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [5.   2.06 4.84 4.16]	 Fitness: 81.39
# Individual 3: [-0.95  2.38  2.06  2.75]	 Fitness: 35.63
# Individual 4: [3.54 2.18 4.26 4.1 ]	 Fitness: 26.45
# Individual 5: [-1.69  2.24  0.03  2.75]	 Fitness: 12.23
#
#  =================================================================
#
# Iteration 791:
# ---------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [5.   2.06 4.84 4.16]	 Fitness: 69.98
# Individual 3: [-0.95  2.38  2.06  2.75]	 Fitness: 18.40
# Individual 4: [3.54 2.18 4.26 4.1 ]	 Fitness: 52.26
# Individual 5: [-1.69  2.24  0.03  2.75]	 Fitness: 15.43
# -----------------------------------------------------------------
# Teacher: [-1.69  2.24  0.03  2.75]	 Fitness: 15.43
# -----------------------------------------------------------------
# Population Mean: [0.18 0.77 1.24 1.75]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-5.   -4.58 -5.   -5.  ]	 Fitness: 100.00
# Individual 2: [4.4  2.1  3.01 3.81]	 Fitness: 69.98
# Individual 3: [-2.83  2.43  0.28  2.08]	 Fitness: 18.40
# Individual 4: [3.02 2.65 4.23 3.79]	 Fitness: 52.26
# Individual 5: [-2.55  2.77 -0.03  2.11]	 Fitness: 15.43
# -----------------------------------------------------------------
# Partner: [-2.83  2.43  0.28  2.08]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [4.66 1.87 2.93 3.82]	 Fitness: 69.98
# Individual 3: [4.35 2.4  2.55 2.96]	 Fitness: 18.40
# Individual 4: [2.51 2.7  5.   4.4 ]	 Fitness: 52.26
# Individual 5: [-0.27  2.76  2.49  2.66]	 Fitness: 15.43
#
#  =================================================================
#
# Iteration 792:
# ---------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [4.66 1.87 2.93 3.82]	 Fitness: 48.33
# Individual 3: [4.35 2.4  2.55 2.96]	 Fitness: 39.99
# Individual 4: [2.51 2.7  5.   4.4 ]	 Fitness: 57.92
# Individual 5: [-0.27  2.76  2.49  2.66]	 Fitness: 21.01
# -----------------------------------------------------------------
# Teacher: [-0.27  2.76  2.49  2.66]	 Fitness: 21.01
# -----------------------------------------------------------------
# Population Mean: [1.25 0.95 1.59 1.77]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-5.   -4.56 -5.   -5.  ]	 Fitness: 100.00
# Individual 2: [3.95 2.36 2.32 3.08]	 Fitness: 48.33
# Individual 3: [3.73 2.56 2.02 2.71]	 Fitness: 39.99
# Individual 4: [0.67 2.87 4.83 4.38]	 Fitness: 57.92
# Individual 5: [-2.12  3.62  2.1   1.81]	 Fitness: 21.01
# -----------------------------------------------------------------
# Partner: [-2.12  3.62  2.1   1.81]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [5.   1.86 2.43 3.27]	 Fitness: 48.33
# Individual 3: [4.39 2.15 2.16 2.9 ]	 Fitness: 39.99
# Individual 4: [-4.79  1.49  3.9   1.39]	 Fitness: 57.92
# Individual 5: [-2.49  2.3   3.64  1.66]	 Fitness: 21.01
#
#  =================================================================
#
# Iteration 793:
# ---------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [5.   1.86 2.43 3.27]	 Fitness: 45.07
# Individual 3: [4.39 2.15 2.16 2.9 ]	 Fitness: 36.97
# Individual 4: [-4.79  1.49  3.9   1.39]	 Fitness: 42.35
# Individual 5: [-2.49  2.3   3.64  1.66]	 Fitness: 27.48
# -----------------------------------------------------------------
# Teacher: [-2.49  2.3   3.64  1.66]	 Fitness: 27.48
# -----------------------------------------------------------------
# Population Mean: [-0.58  0.56  1.43  0.84]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-5.   -4.69 -4.24 -5.  ]	 Fitness: 100.00
# Individual 2: [4.11 2.18 2.48 3.27]	 Fitness: 45.07
# Individual 3: [3.84 2.89 2.83 2.88]	 Fitness: 36.97
# Individual 4: [-5.    2.57  4.57  1.38]	 Fitness: 42.35
# Individual 5: [-3.38  3.18  4.27  1.65]	 Fitness: 27.48
# -----------------------------------------------------------------
# Partner: [3.84 2.89 2.83 2.88]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [-3.52  1.82 -2.94 -0.12]	 Fitness: 45.07
# Individual 3: [-4.64  2.71  2.98  1.43]	 Fitness: 36.97
# Individual 4: [-5.    2.48  5.    1.38]	 Fitness: 42.35
# Individual 5: [-3.4   3.09  4.78  1.47]	 Fitness: 27.48
#
#  =================================================================
#
# Iteration 794:
# ---------------
# Individual 1: [-5. -5. -5. -5.]	 Fitness: 100.00
# Individual 2: [-3.52  1.82 -2.94 -0.12]	 Fitness: 24.35
# Individual 3: [-4.64  2.71  2.98  1.43]	 Fitness: 39.76
# Individual 4: [-5.    2.48  5.    1.38]	 Fitness: 58.05
# Individual 5: [-3.4   3.09  4.78  1.47]	 Fitness: 46.11
# -----------------------------------------------------------------
# Teacher: [-3.52  1.82 -2.94 -0.12]	 Fitness: 24.35
# -----------------------------------------------------------------
# Population Mean: [-4.31  1.02  0.96 -0.17]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-4.43 -5.   -5.   -4.97]	 Fitness: 100.00
# Individual 2: [-3.3   1.78 -4.48 -0.05]	 Fitness: 24.35
# Individual 3: [-4.28  2.64 -1.59  1.47]	 Fitness: 39.76
# Individual 4: [-0.91  2.31  3.1   1.58]	 Fitness: 58.05
# Individual 5: [-2.35  2.96  0.92  1.68]	 Fitness: 46.11
# -----------------------------------------------------------------
# Partner: [-3.3   1.78 -4.48 -0.05]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-4.43 -5.   -5.   -4.97]	 Fitness: 100.00
# Individual 2: [-4.33 -2.53 -4.74 -3.74]	 Fitness: 24.35
# Individual 3: [-3.04  2.77 -1.24  1.58]	 Fitness: 39.76
# Individual 4: [0.32 5.   5.   2.07]	 Fitness: 58.05
# Individual 5: [-0.91  4.34  1.69  1.72]	 Fitness: 46.11
#
#  =================================================================
#
# Iteration 795:
# ---------------
# Individual 1: [-4.43 -5.   -5.   -4.97]	 Fitness: 94.33
# Individual 2: [-4.33 -2.53 -4.74 -3.74]	 Fitness: 61.56
# Individual 3: [-3.04  2.77 -1.24  1.58]	 Fitness: 20.95
# Individual 4: [0.32 5.   5.   2.07]	 Fitness: 54.39
# Individual 5: [-0.91  4.34  1.69  1.72]	 Fitness: 25.47
# -----------------------------------------------------------------
# Teacher: [-3.04  2.77 -1.24  1.58]	 Fitness: 20.95
# -----------------------------------------------------------------
# Population Mean: [-2.48  0.92 -0.86 -0.67]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-3.56 -4.84 -4.73 -4.56]	 Fitness: 94.33
# Individual 2: [-3.85 -1.69 -4.52 -2.42]	 Fitness: 61.56
# Individual 3: [-2.54  3.66 -1.13  2.79]	 Fitness: 20.95
# Individual 4: [1.07 5.   5.   4.45]	 Fitness: 54.39
# Individual 5: [-0.    4.59  2.14  2.33]	 Fitness: 25.47
# -----------------------------------------------------------------
# Partner: [-0.    4.59  2.14  2.33]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-3.56 -4.84 -4.73 -4.56]	 Fitness: 94.33
# Individual 2: [-5.   -4.41 -5.   -3.07]	 Fitness: 61.56
# Individual 3: [-1.99  4.41 -0.28  2.53]	 Fitness: 20.95
# Individual 4: [2.99 5.   5.   4.74]	 Fitness: 54.39
# Individual 5: [1.45 4.69 2.56 2.22]	 Fitness: 25.47
#
#  =================================================================
#
# Iteration 796:
# ---------------
# Individual 1: [-3.56 -4.84 -4.73 -4.56]	 Fitness: 79.30
# Individual 2: [-5.   -4.41 -5.   -3.07]	 Fitness: 78.93
# Individual 3: [-1.99  4.41 -0.28  2.53]	 Fitness: 29.89
# Individual 4: [2.99 5.   5.   4.74]	 Fitness: 81.40
# Individual 5: [1.45 4.69 2.56 2.22]	 Fitness: 35.65
# -----------------------------------------------------------------
# Teacher: [-1.99  4.41 -0.28  2.53]	 Fitness: 29.89
# -----------------------------------------------------------------
# Population Mean: [-1.22  0.97 -0.49  0.37]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-3.29 -4.44 -4.11 -3.55]	 Fitness: 79.30
# Individual 2: [-4.83 -2.67 -4.96 -3.01]	 Fitness: 78.93
# Individual 3: [-1.95  5.   -0.2   3.67]	 Fitness: 29.89
# Individual 4: [3.14 5.   5.   5.  ]	 Fitness: 81.40
# Individual 5: [1.61 5.   2.62 2.33]	 Fitness: 35.65
# -----------------------------------------------------------------
# Partner: [1.61 5.   2.62 2.33]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [ 1.09  1.56 -1.7   0.55]	 Fitness: 79.30
# Individual 2: [-1.05  1.4  -4.41 -2.7 ]	 Fitness: 78.93
# Individual 3: [2.81 5.   4.83 4.52]	 Fitness: 29.89
# Individual 4: [3.94 5.   5.   5.  ]	 Fitness: 81.40
# Individual 5: [0.55 5.   1.1  0.26]	 Fitness: 35.65
#
#  =================================================================
#
# Iteration 797:
# ---------------
# Individual 1: [ 1.09  1.56 -1.7   0.55]	 Fitness: 6.84
# Individual 2: [-1.05  1.4  -4.41 -2.7 ]	 Fitness: 29.81
# Individual 3: [2.81 5.   4.83 4.52]	 Fitness: 76.58
# Individual 4: [3.94 5.   5.   5.  ]	 Fitness: 90.50
# Individual 5: [0.55 5.   1.1  0.26]	 Fitness: 26.57
# -----------------------------------------------------------------
# Teacher: [ 1.09  1.56 -1.7   0.55]	 Fitness: 6.84
# -----------------------------------------------------------------
# Population Mean: [1.47 3.59 0.96 1.52]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [ 0.64 -2.15 -3.34 -0.73]	 Fitness: 6.84
# Individual 2: [-2.16  0.15 -5.   -3.9 ]	 Fitness: 29.81
# Individual 3: [ 2.11 -0.21  3.99  3.01]	 Fitness: 76.58
# Individual 4: [2.52 4.56 2.47 3.53]	 Fitness: 90.50
# Individual 5: [ 0.33  4.98 -2.   -1.23]	 Fitness: 26.57
# -----------------------------------------------------------------
# Partner: [ 2.11 -0.21  3.99  3.01]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [ 0.79 -1.98  3.34  0.47]	 Fitness: 6.84
# Individual 2: [-2.89  1.83 -5.   -4.23]	 Fitness: 29.81
# Individual 3: [2.29 0.88 3.37 3.03]	 Fitness: 76.58
# Individual 4: [3.64 4.42 5.   3.58]	 Fitness: 90.50
# Individual 5: [-1.43  2.08 -2.6  -2.09]	 Fitness: 26.57
#
#  =================================================================
#
# Iteration 798:
# ---------------
# Individual 1: [ 0.79 -1.98  3.34  0.47]	 Fitness: 15.91
# Individual 2: [-2.89  1.83 -5.   -4.23]	 Fitness: 54.57
# Individual 3: [2.29 0.88 3.37 3.03]	 Fitness: 26.55
# Individual 4: [3.64 4.42 5.   3.58]	 Fitness: 70.54
# Individual 5: [-1.43  2.08 -2.6  -2.09]	 Fitness: 17.49
# -----------------------------------------------------------------
# Teacher: [ 0.79 -1.98  3.34  0.47]	 Fitness: 15.91
# -----------------------------------------------------------------
# Population Mean: [0.48 1.45 0.82 0.15]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [ 0.75 -2.1   4.2   0.59]	 Fitness: 15.91
# Individual 2: [-2.91 -1.67 -4.97 -4.22]	 Fitness: 54.57
# Individual 3: [ 2.22 -0.53  3.54  3.06]	 Fitness: 26.55
# Individual 4: [3.53 3.8  5.   3.66]	 Fitness: 70.54
# Individual 5: [-1.52  1.13 -2.46 -2.05]	 Fitness: 17.49
# -----------------------------------------------------------------
# Partner: [ 0.75 -2.1   4.2   0.59]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [ 0.32 -0.34 -1.96 -1.46]	 Fitness: 15.91
# Individual 2: [-3.67 -2.37 -5.   -5.  ]	 Fitness: 54.57
# Individual 3: [ 3.59 -0.7   5.    3.77]	 Fitness: 26.55
# Individual 4: [5.   5.   5.   4.71]	 Fitness: 70.54
# Individual 5: [ 1.32  2.32 -1.71 -1.97]	 Fitness: 17.49
#
#  =================================================================
#
# Iteration 799:
# ---------------
# Individual 1: [ 0.32 -0.34 -1.96 -1.46]	 Fitness: 6.21
# Individual 2: [-3.67 -2.37 -5.   -5.  ]	 Fitness: 69.10
# Individual 3: [ 3.59 -0.7   5.    3.77]	 Fitness: 52.63
# Individual 4: [5.   5.   5.   4.71]	 Fitness: 97.19
# Individual 5: [ 1.32  2.32 -1.71 -1.97]	 Fitness: 13.94
# -----------------------------------------------------------------
# Teacher: [ 0.32 -0.34 -1.96 -1.46]	 Fitness: 6.21
# -----------------------------------------------------------------
# Population Mean: [1.31 0.78 0.27 0.01]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-1.04 -0.99 -4.41 -2.33]	 Fitness: 6.21
# Individual 2: [-4.77 -3.49 -5.   -5.  ]	 Fitness: 69.10
# Individual 3: [ 2.5  -2.43  4.4   3.19]	 Fitness: 52.63
# Individual 4: [4.86 3.28 3.45 3.58]	 Fitness: 97.19
# Individual 5: [-0.3   1.83 -3.96 -2.11]	 Fitness: 13.94
# -----------------------------------------------------------------
# Partner: [4.86 3.28 3.45 3.58]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-0.94 -1.57  2.32  0.78]	 Fitness: 6.21
# Individual 2: [-0.73 -0.26 -0.75 -4.59]	 Fitness: 69.10
# Individual 3: [ 2.42 -2.35  2.    2.82]	 Fitness: 52.63
# Individual 4: [5.   4.39 3.89 5.  ]	 Fitness: 97.19
# Individual 5: [-0.49  0.16 -1.14 -3.68]	 Fitness: 13.94
#
#  =================================================================
#
# Iteration 800:
# ---------------
# Individual 1: [-0.94 -1.57  2.32  0.78]	 Fitness: 9.34
# Individual 2: [-0.73 -0.26 -0.75 -4.59]	 Fitness: 22.23
# Individual 3: [ 2.42 -2.35  2.    2.82]	 Fitness: 23.38
# Individual 4: [5.   4.39 3.89 5.  ]	 Fitness: 84.40
# Individual 5: [-0.49  0.16 -1.14 -3.68]	 Fitness: 15.09
# -----------------------------------------------------------------
# Teacher: [-0.94 -1.57  2.32  0.78]	 Fitness: 9.34
# -----------------------------------------------------------------
# Population Mean: [1.05 0.07 1.26 0.07]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-3.75 -2.24  2.17  1.11]	 Fitness: 9.34
# Individual 2: [-2.3  -1.81 -0.77 -4.1 ]	 Fitness: 22.23
# Individual 3: [ 0.2  -4.06  1.83  3.32]	 Fitness: 23.38
# Individual 4: [4.8  2.76 3.84 5.  ]	 Fitness: 84.40
# Individual 5: [-2.57 -0.85 -1.31 -3.34]	 Fitness: 15.09
# -----------------------------------------------------------------
# Partner: [4.8  2.76 3.84 5.  ]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-1.51  0.28  2.99  2.  ]	 Fitness: 9.34
# Individual 2: [-1.26 -1.91 -0.01 -1.77]	 Fitness: 22.23
# Individual 3: [ 0.32 -5.    1.28  3.83]	 Fitness: 23.38
# Individual 4: [4.8  2.76 3.84 5.  ]	 Fitness: 84.40
# Individual 5: [-3.04 -1.77 -4.28 -5.  ]	 Fitness: 15.09
#
#  =================================================================
#
# Iteration 801:
# ---------------
# Individual 1: [-1.51  0.28  2.99  2.  ]	 Fitness: 15.28
# Individual 2: [-1.26 -1.91 -0.01 -1.77]	 Fitness: 8.39
# Individual 3: [ 0.32 -5.    1.28  3.83]	 Fitness: 41.38
# Individual 4: [4.8  2.76 3.84 5.  ]	 Fitness: 70.42
# Individual 5: [-3.04 -1.77 -4.28 -5.  ]	 Fitness: 55.67
# -----------------------------------------------------------------
# Teacher: [-1.26 -1.91 -0.01 -1.77]	 Fitness: 8.39
# -----------------------------------------------------------------
# Population Mean: [-0.14 -1.13  0.76  0.81]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-1.91  0.39  2.43 -0.09]	 Fitness: 15.28
# Individual 2: [-1.52 -1.58 -1.09 -4.59]	 Fitness: 8.39
# Individual 3: [-0.28 -4.87  0.62  0.92]	 Fitness: 41.38
# Individual 4: [4.55 2.9  3.33 4.4 ]	 Fitness: 70.42
# Individual 5: [-3.1  -1.72 -5.   -5.  ]	 Fitness: 55.67
# -----------------------------------------------------------------
# Partner: [-1.91  0.39  2.43 -0.09]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-2.03  1.04  2.47  1.69]	 Fitness: 15.28
# Individual 2: [-1.04 -4.49  0.17 -0.15]	 Fitness: 8.39
# Individual 3: [-0.28 -4.87  0.62  0.92]	 Fitness: 41.38
# Individual 4: [4.55 5.   5.   5.  ]	 Fitness: 70.42
# Individual 5: [-3.55 -3.12 -5.   -5.  ]	 Fitness: 55.67
#
#  =================================================================
#
# Iteration 802:
# ---------------
# Individual 1: [-2.03  1.04  2.47  1.69]	 Fitness: 14.17
# Individual 2: [-1.04 -4.49  0.17 -0.15]	 Fitness: 21.27
# Individual 3: [-0.28 -4.87  0.62  0.92]	 Fitness: 25.02
# Individual 4: [4.55 5.   5.   5.  ]	 Fitness: 95.73
# Individual 5: [-3.55 -3.12 -5.   -5.  ]	 Fitness: 72.33
# -----------------------------------------------------------------
# Teacher: [-2.03  1.04  2.47  1.69]	 Fitness: 14.17
# -----------------------------------------------------------------
# Population Mean: [-0.47 -1.29  0.65  0.49]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-2.63  2.69  3.15  2.07]	 Fitness: 14.17
# Individual 2: [-1.63 -0.87  0.8   0.21]	 Fitness: 21.27
# Individual 3: [-1.34 -1.53  1.39  1.32]	 Fitness: 25.02
# Individual 4: [3.68 5.   5.   5.  ]	 Fitness: 95.73
# Individual 5: [-4.14 -1.76 -4.96 -4.68]	 Fitness: 72.33
# -----------------------------------------------------------------
# Partner: [3.68 5.   5.   5.  ]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-2.63  2.69  3.15  2.07]	 Fitness: 14.17
# Individual 2: [-1.47 -1.53  0.92  0.24]	 Fitness: 21.27
# Individual 3: [3.3  4.09 1.88 4.57]	 Fitness: 25.02
# Individual 4: [3.68 5.   5.   5.  ]	 Fitness: 95.73
# Individual 5: [-5.   -1.92 -5.   -5.  ]	 Fitness: 72.33
#
#  =================================================================
#
# Iteration 803:
# ---------------
# Individual 1: [-2.63  2.69  3.15  2.07]	 Fitness: 28.34
# Individual 2: [-1.47 -1.53  0.92  0.24]	 Fitness: 5.38
# Individual 3: [3.3  4.09 1.88 4.57]	 Fitness: 52.06
# Individual 4: [3.68 5.   5.   5.  ]	 Fitness: 88.53
# Individual 5: [-5.   -1.92 -5.   -5.  ]	 Fitness: 78.68
# -----------------------------------------------------------------
# Teacher: [-1.47 -1.53  0.92  0.24]	 Fitness: 5.38
# -----------------------------------------------------------------
# Population Mean: [-0.42  1.67  1.19  1.37]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-2.66 -1.7   2.96  1.36]	 Fitness: 28.34
# Individual 2: [-1.84 -4.23  0.5  -1.34]	 Fitness: 5.38
# Individual 3: [ 2.69 -0.46  1.4   4.3 ]	 Fitness: 52.06
# Individual 4: [3.51 4.23 3.6  2.88]	 Fitness: 88.53
# Individual 5: [-5.   -4.15 -5.   -5.  ]	 Fitness: 78.68
# -----------------------------------------------------------------
# Partner: [3.51 4.23 3.6  2.88]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-3.29 -1.48  4.76  3.6 ]	 Fitness: 28.34
# Individual 2: [-1.84 -4.23  0.5  -1.34]	 Fitness: 5.38
# Individual 3: [3.36 3.13 1.7  2.93]	 Fitness: 52.06
# Individual 4: [4.86 5.   5.   4.73]	 Fitness: 88.53
# Individual 5: [-5. -5. -5. -5.]	 Fitness: 78.68
#
#  =================================================================
#
# Iteration 804:
# ---------------
# Individual 1: [-3.29 -1.48  4.76  3.6 ]	 Fitness: 48.67
# Individual 2: [-1.84 -4.23  0.5  -1.34]	 Fitness: 23.33
# Individual 3: [3.36 3.13 1.7  2.93]	 Fitness: 32.59
# Individual 4: [4.86 5.   5.   4.73]	 Fitness: 95.95
# Individual 5: [-5. -5. -5. -5.]	 Fitness: 100.00
# -----------------------------------------------------------------
# Teacher: [-1.84 -4.23  0.5  -1.34]	 Fitness: 23.33
# -----------------------------------------------------------------
# Population Mean: [-0.38 -0.51  1.39  0.98]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-3.86 -2.02  2.84  2.98]	 Fitness: 48.67
# Individual 2: [-1.85 -5.    0.26 -3.53]	 Fitness: 23.33
# Individual 3: [2.84 2.71 0.79 2.38]	 Fitness: 32.59
# Individual 4: [4.63 2.66 3.2  2.93]	 Fitness: 95.95
# Individual 5: [-5. -5. -5. -5.]	 Fitness: 100.00
# -----------------------------------------------------------------
# Partner: [-1.85 -5.    0.26 -3.53]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5.   -5.    3.31  3.49]	 Fitness: 48.67
# Individual 2: [-2.65 -5.    0.9  -1.69]	 Fitness: 23.33
# Individual 3: [4.51 2.7  2.94 2.57]	 Fitness: 32.59
# Individual 4: [4.73 2.63 3.35 3.14]	 Fitness: 95.95
# Individual 5: [-5. -5. -5. -5.]	 Fitness: 100.00
#
#  =================================================================
#
# Iteration 805:
# ---------------
# Individual 1: [-5.   -5.    3.31  3.49]	 Fitness: 73.13
# Individual 2: [-2.65 -5.    0.9  -1.69]	 Fitness: 35.71
# Individual 3: [4.51 2.7  2.94 2.57]	 Fitness: 42.89
# Individual 4: [4.73 2.63 3.35 3.14]	 Fitness: 50.40
# Individual 5: [-5. -5. -5. -5.]	 Fitness: 100.00
# -----------------------------------------------------------------
# Teacher: [-2.65 -5.    0.9  -1.69]	 Fitness: 35.71
# -----------------------------------------------------------------
# Population Mean: [-0.68 -1.93  1.1   0.5 ]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-5.   -5.    2.35  1.94]	 Fitness: 73.13
# Individual 2: [-3.22 -5.    0.57 -2.06]	 Fitness: 35.71
# Individual 3: [4.25 1.65 2.54 2.12]	 Fitness: 42.89
# Individual 4: [4.03 1.85 3.24 3.11]	 Fitness: 50.40
# Individual 5: [-5. -5. -5. -5.]	 Fitness: 100.00
# -----------------------------------------------------------------
# Partner: [4.03 1.85 3.24 3.11]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5.   -5.    1.23 -4.38]	 Fitness: 73.13
# Individual 2: [ 2.73 -1.27  2.   -0.93]	 Fitness: 35.71
# Individual 3: [4.86 1.7  2.81 4.46]	 Fitness: 42.89
# Individual 4: [ 3.99  1.63 -0.94  0.89]	 Fitness: 50.40
# Individual 5: [-5. -5. -5. -5.]	 Fitness: 100.00
#
#  =================================================================
#
# Iteration 806:
# ---------------
# Individual 1: [-5.   -5.    1.23 -4.38]	 Fitness: 70.75
# Individual 2: [ 2.73 -1.27  2.   -0.93]	 Fitness: 13.96
# Individual 3: [4.86 1.7  2.81 4.46]	 Fitness: 54.32
# Individual 4: [ 3.99  1.63 -0.94  0.89]	 Fitness: 20.28
# Individual 5: [-5. -5. -5. -5.]	 Fitness: 100.00
# -----------------------------------------------------------------
# Teacher: [ 2.73 -1.27  2.   -0.93]	 Fitness: 13.96
# -----------------------------------------------------------------
# Population Mean: [ 0.32 -1.59  0.02 -0.99]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-3.08 -4.13  2.52 -3.56]	 Fitness: 70.75
# Individual 2: [ 2.83 -0.79  2.51 -0.2 ]	 Fitness: 13.96
# Individual 3: [5.   2.65 3.44 5.  ]	 Fitness: 54.32
# Individual 4: [5.   3.18 0.17 0.91]	 Fitness: 20.28
# Individual 5: [-3.59 -3.79 -3.92 -4.29]	 Fitness: 100.00
# -----------------------------------------------------------------
# Partner: [-3.08 -4.13  2.52 -3.56]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-3.08 -4.13  2.52 -3.56]	 Fitness: 70.75
# Individual 2: [ 2.16 -2.82  2.51 -3.34]	 Fitness: 13.96
# Individual 3: [5.   2.24 4.57 5.  ]	 Fitness: 54.32
# Individual 4: [2.68 2.98 0.14 0.52]	 Fitness: 20.28
# Individual 5: [-3.95 -3.66 -5.   -4.63]	 Fitness: 100.00
#
#  =================================================================
#
# Iteration 807:
# ---------------
# Individual 1: [-3.08 -4.13  2.52 -3.56]	 Fitness: 45.57
# Individual 2: [ 2.16 -2.82  2.51 -3.34]	 Fitness: 30.04
# Individual 3: [5.   2.24 4.57 5.  ]	 Fitness: 75.95
# Individual 4: [2.68 2.98 0.14 0.52]	 Fitness: 16.33
# Individual 5: [-3.95 -3.66 -5.   -4.63]	 Fitness: 75.41
# -----------------------------------------------------------------
# Teacher: [2.68 2.98 0.14 0.52]	 Fitness: 16.33
# -----------------------------------------------------------------
# Population Mean: [ 0.56 -1.08  0.95 -1.2 ]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-2.32 -3.24  1.01 -1.54]	 Fitness: 45.57
# Individual 2: [ 3.63  1.3   2.31 -3.02]	 Fitness: 30.04
# Individual 3: [5.   2.5  3.83 5.  ]	 Fitness: 75.95
# Individual 4: [3.66 5.   0.13 3.38]	 Fitness: 16.33
# Individual 5: [-3.32  1.2  -5.   -3.21]	 Fitness: 75.41
# -----------------------------------------------------------------
# Partner: [3.66 5.   0.13 3.38]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-2.94 -0.83 -4.78 -2.88]	 Fitness: 45.57
# Individual 2: [ 3.63  1.3   2.31 -3.02]	 Fitness: 30.04
# Individual 3: [5.   3.4  4.94 5.  ]	 Fitness: 75.95
# Individual 4: [4.88 3.65 2.9  4.77]	 Fitness: 16.33
# Individual 5: [0.2  1.52 1.98 4.12]	 Fitness: 75.41
#
#  =================================================================
#
# Iteration 808:
# ---------------
# Individual 1: [-2.94 -0.83 -4.78 -2.88]	 Fitness: 40.48
# Individual 2: [ 3.63  1.3   2.31 -3.02]	 Fitness: 29.27
# Individual 3: [5.   3.4  4.94 5.  ]	 Fitness: 85.95
# Individual 4: [4.88 3.65 2.9  4.77]	 Fitness: 68.34
# Individual 5: [0.2  1.52 1.98 4.12]	 Fitness: 23.25
# -----------------------------------------------------------------
# Teacher: [0.2  1.52 1.98 4.12]	 Fitness: 23.25
# -----------------------------------------------------------------
# Population Mean: [2.15 1.81 1.47 1.6 ]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-3.7  -2.09 -5.   -2.7 ]	 Fitness: 40.48
# Individual 2: [-0.11  0.86  1.7  -2.12]	 Fitness: 29.27
# Individual 3: [2.97 1.72 4.2  5.  ]	 Fitness: 85.95
# Individual 4: [4.76 1.9  2.64 5.  ]	 Fitness: 68.34
# Individual 5: [-0.77  1.15  1.94  4.85]	 Fitness: 23.25
# -----------------------------------------------------------------
# Partner: [2.97 1.72 4.2  5.  ]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [ 1.17  0.56  1.37 -2.23]	 Fitness: 40.48
# Individual 2: [ 0.43  0.57  1.54 -5.  ]	 Fitness: 29.27
# Individual 3: [4.71 2.47 5.   5.  ]	 Fitness: 85.95
# Individual 4: [5.   2.23 2.67 5.  ]	 Fitness: 68.34
# Individual 5: [1.41 2.   2.51 4.92]	 Fitness: 23.25
#
#  =================================================================
#
# Iteration 809:
# ---------------
# Individual 1: [ 1.17  0.56  1.37 -2.23]	 Fitness: 8.53
# Individual 2: [ 0.43  0.57  1.54 -5.  ]	 Fitness: 27.89
# ...
# Individual 1: [-1.35 -3.5   5.    0.29]	 Fitness: 33.32
# Individual 2: [ 0.7   0.06 -1.23 -1.18]	 Fitness: 13.87
# Individual 3: [ 5.   -3.59  5.    2.03]	 Fitness: 73.21
# Individual 4: [-5.    3.35 -5.   -5.  ]	 Fitness: 75.15
# Individual 5: [-5.  5. -5.  5.]	 Fitness: 79.89
#
#  =================================================================
#
# Iteration 924:
# ---------------
# Individual 1: [-1.35 -3.5   5.    0.29]	 Fitness: 39.14
# Individual 2: [ 0.7   0.06 -1.23 -1.18]	 Fitness: 3.41
# Individual 3: [ 5.   -3.59  5.    2.03]	 Fitness: 67.00
# Individual 4: [-5.    3.35 -5.   -5.  ]	 Fitness: 86.21
# Individual 5: [-5.  5. -5.  5.]	 Fitness: 100.00
# -----------------------------------------------------------------
# Teacher: [ 0.7   0.06 -1.23 -1.18]	 Fitness: 3.41
# -----------------------------------------------------------------
# Population Mean: [-1.13  0.26 -0.25  0.23]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [ 0.41 -3.84  4.42 -1.12]	 Fitness: 39.14
# Individual 2: [ 2.21 -0.18 -1.55 -2.55]	 Fitness: 3.41
# Individual 3: [ 5.   -3.91  4.86  0.69]	 Fitness: 67.00
# Individual 4: [-4.    2.97 -5.   -5.  ]	 Fitness: 86.21
# Individual 5: [-3.39  4.55 -5.    4.81]	 Fitness: 100.00
# -----------------------------------------------------------------
# Partner: [-3.39  4.55 -5.    4.81]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [ 0.41 -3.84  4.42 -1.12]	 Fitness: 39.14
# Individual 2: [-3.98 -0.14 -1.83 -4.32]	 Fitness: 3.41
# Individual 3: [ 5.   -3.97  5.    1.52]	 Fitness: 67.00
# Individual 4: [-4.02  5.   -5.   -5.  ]	 Fitness: 86.21
# Individual 5: [-4.15  5.   -5.    5.  ]	 Fitness: 100.00
#
#  =================================================================
#
# Iteration 925:
# ---------------
# Individual 1: [ 0.41 -3.84  4.42 -1.12]	 Fitness: 35.65
# Individual 2: [-3.98 -0.14 -1.83 -4.32]	 Fitness: 37.89
# Individual 3: [ 5.   -3.97  5.    1.52]	 Fitness: 68.07
# Individual 4: [-4.02  5.   -5.   -5.  ]	 Fitness: 91.17
# Individual 5: [-4.15  5.   -5.    5.  ]	 Fitness: 92.25
# -----------------------------------------------------------------
# Teacher: [ 0.41 -3.84  4.42 -1.12]	 Fitness: 35.65
# -----------------------------------------------------------------
# Population Mean: [-1.35  0.41 -0.48 -0.79]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [ 2.63 -5.    5.   -0.72]	 Fitness: 35.65
# Individual 2: [-3.22 -1.73 -0.69 -4.31]	 Fitness: 37.89
# Individual 3: [ 5.   -5.    5.    1.73]	 Fitness: 68.07
# Individual 4: [-3.89  4.44 -1.   -4.66]	 Fitness: 91.17
# Individual 5: [-2.2   2.14 -1.18  5.  ]	 Fitness: 92.25
# -----------------------------------------------------------------
# Partner: [-3.22 -1.73 -0.69 -4.31]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [ 2.63 -5.    5.   -0.72]	 Fitness: 35.65
# Individual 2: [-2.45  1.14 -1.15  4.89]	 Fitness: 37.89
# Individual 3: [ 5.   -5.    5.    0.65]	 Fitness: 68.07
# Individual 4: [-5.  5. -5. -5.]	 Fitness: 91.17
# Individual 5: [-1.52  1.22 -0.33  5.  ]	 Fitness: 92.25
#
#  =================================================================
#
# Iteration 926:
# ---------------
# Individual 1: [ 2.63 -5.    5.   -0.72]	 Fitness: 57.46
# Individual 2: [-2.45  1.14 -1.15  4.89]	 Fitness: 32.50
# Individual 3: [ 5.   -5.    5.    0.65]	 Fitness: 75.42
# Individual 4: [-5.  5. -5. -5.]	 Fitness: 100.00
# Individual 5: [-1.52  1.22 -0.33  5.  ]	 Fitness: 28.91
# -----------------------------------------------------------------
# Teacher: [-1.52  1.22 -0.33  5.  ]	 Fitness: 28.91
# -----------------------------------------------------------------
# Population Mean: [-0.27 -0.53  0.7   0.96]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [ 1.91 -4.96  4.54  2.16]	 Fitness: 57.46
# Individual 2: [-2.83  2.46 -2.33  5.  ]	 Fitness: 32.50
# Individual 3: [ 4.05 -4.45  3.62  2.9 ]	 Fitness: 75.42
# Individual 4: [-5.   5.  -5.  -4.7]	 Fitness: 100.00
# Individual 5: [-2.45  1.62 -1.02  5.  ]	 Fitness: 28.91
# -----------------------------------------------------------------
# Partner: [-5.   5.  -5.  -4.7]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [ 4.72 -5.    5.    1.6 ]	 Fitness: 57.46
# Individual 2: [ 3.44 -1.82 -1.19  4.44]	 Fitness: 32.50
# Individual 3: [ 3.71 -4.21  2.72  3.82]	 Fitness: 75.42
# Individual 4: [-5.   5.  -5.  -4.7]	 Fitness: 100.00
# Individual 5: [-3.04  2.43 -1.55  1.12]	 Fitness: 28.91
#
#  =================================================================
#
# Iteration 927:
# ---------------
# Individual 1: [ 4.72 -5.    5.    1.6 ]	 Fitness: 74.87
# Individual 2: [ 3.44 -1.82 -1.19  4.44]	 Fitness: 36.29
# Individual 3: [ 3.71 -4.21  2.72  3.82]	 Fitness: 53.48
# Individual 4: [-5.   5.  -5.  -4.7]	 Fitness: 97.09
# Individual 5: [-3.04  2.43 -1.55  1.12]	 Fitness: 18.77
# -----------------------------------------------------------------
# Teacher: [-3.04  2.43 -1.55  1.12]	 Fitness: 18.77
# -----------------------------------------------------------------
# Population Mean: [ 0.77 -0.72 -0.    1.25]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [ 0.42 -4.82  4.61  0.83]	 Fitness: 74.87
# Individual 2: [ 1.2  -1.18 -1.75  3.85]	 Fitness: 36.29
# Individual 3: [ 2.72 -4.14  2.63  2.5 ]	 Fitness: 53.48
# Individual 4: [-5.  5. -5. -5.]	 Fitness: 97.09
# Individual 5: [-5.    4.88 -1.76  0.69]	 Fitness: 18.77
# -----------------------------------------------------------------
# Partner: [ 2.72 -4.14  2.63  2.5 ]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [ 0.42 -4.82  4.61  0.83]	 Fitness: 74.87
# Individual 2: [ 0.86 -2.56  3.65  0.92]	 Fitness: 36.29
# Individual 3: [ 0.78  1.58 -1.98 -4.91]	 Fitness: 53.48
# Individual 4: [-5.  5. -5. -5.]	 Fitness: 97.09
# Individual 5: [0.63 4.83 1.93 0.83]	 Fitness: 18.77
#
#  =================================================================
#
# Iteration 928:
# ---------------
# Individual 1: [ 0.42 -4.82  4.61  0.83]	 Fitness: 45.30
# Individual 2: [ 0.86 -2.56  3.65  0.92]	 Fitness: 21.43
# Individual 3: [ 0.78  1.58 -1.98 -4.91]	 Fitness: 31.15
# Individual 4: [-5.  5. -5. -5.]	 Fitness: 100.00
# Individual 5: [0.63 4.83 1.93 0.83]	 Fitness: 28.10
# -----------------------------------------------------------------
# Teacher: [ 0.86 -2.56  3.65  0.92]	 Fitness: 21.43
# -----------------------------------------------------------------
# Population Mean: [-0.46  0.81  0.64 -1.47]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [ 0.79 -5.    5.    3.39]	 Fitness: 45.30
# Individual 2: [ 2.2  -5.    4.9   2.76]	 Fitness: 21.43
# Individual 3: [ 0.82 -1.84 -1.7  -1.62]	 Fitness: 31.15
# Individual 4: [-3.23  1.8  -3.56 -4.78]	 Fitness: 100.00
# Individual 5: [1.81 0.7  2.45 3.74]	 Fitness: 28.10
# -----------------------------------------------------------------
# Partner: [ 0.79 -5.    5.    3.39]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-1.77  0.    4.03  3.12]	 Fitness: 45.30
# Individual 2: [ 2.2  -5.    4.9   2.76]	 Fitness: 21.43
# Individual 3: [ 0.82 -1.84 -1.7  -1.62]	 Fitness: 31.15
# Individual 4: [-4.84  5.   -5.   -5.  ]	 Fitness: 100.00
# Individual 5: [-0.19  0.58  3.25  3.13]	 Fitness: 28.10
#
#  =================================================================
#
# Iteration 929:
# ---------------
# Individual 1: [-1.77  0.    4.03  3.12]	 Fitness: 29.12
# Individual 2: [ 2.2  -5.    4.9   2.76]	 Fitness: 61.47
# Individual 3: [ 0.82 -1.84 -1.7  -1.62]	 Fitness: 9.58
# Individual 4: [-4.84  5.   -5.   -5.  ]	 Fitness: 98.41
# Individual 5: [-0.19  0.58  3.25  3.13]	 Fitness: 20.71
# -----------------------------------------------------------------
# Teacher: [ 0.82 -1.84 -1.7  -1.62]	 Fitness: 9.58
# -----------------------------------------------------------------
# Population Mean: [-0.76 -0.25  1.1   0.48]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-1.36 -0.15  3.76  0.91]	 Fitness: 29.12
# Individual 2: [ 3.87 -5.    1.93  1.03]	 Fitness: 61.47
# Individual 3: [ 2.91 -2.52 -5.   -3.3 ]	 Fitness: 9.58
# Individual 4: [-4.65  4.49 -5.   -5.  ]	 Fitness: 98.41
# Individual 5: [1.72 0.2  2.18 2.8 ]	 Fitness: 20.71
# -----------------------------------------------------------------
# Partner: [ 2.91 -2.52 -5.   -3.3 ]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-2.99  3.22 -1.8  -2.67]	 Fitness: 29.12
# Individual 2: [ 2.6   1.09  0.42 -4.32]	 Fitness: 61.47
# Individual 3: [ 2.11  0.1  -4.26  0.93]	 Fitness: 9.58
# Individual 4: [-5.  5. -5. -5.]	 Fitness: 98.41
# Individual 5: [ 2.23  0.67  1.79 -1.76]	 Fitness: 20.71
#
#  =================================================================
#
# Iteration 930:
# ---------------
# Individual 1: [-2.99  3.22 -1.8  -2.67]	 Fitness: 29.65
# Individual 2: [ 2.6   1.09  0.42 -4.32]	 Fitness: 26.82
# Individual 3: [ 2.11  0.1  -4.26  0.93]	 Fitness: 23.47
# Individual 4: [-5.  5. -5. -5.]	 Fitness: 100.00
# Individual 5: [ 2.23  0.67  1.79 -1.76]	 Fitness: 11.74
# -----------------------------------------------------------------
# Teacher: [ 2.23  0.67  1.79 -1.76]	 Fitness: 11.74
# -----------------------------------------------------------------
# Population Mean: [-0.21  2.01 -1.77 -2.56]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-1.59 -0.13 -0.59  0.19]	 Fitness: 29.65
# Individual 2: [ 3.46 -1.52  1.2  -2.83]	 Fitness: 26.82
# Individual 3: [ 3.92 -0.38 -0.99  4.22]	 Fitness: 23.47
# Individual 4: [-4.89  1.66 -4.8  -3.77]	 Fitness: 100.00
# Individual 5: [ 2.29 -1.59  5.   -0.07]	 Fitness: 11.74
# -----------------------------------------------------------------
# Partner: [ 3.46 -1.52  1.2  -2.83]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-4.55  0.07 -0.26 -0.1 ]	 Fitness: 29.65
# Individual 2: [-2.45 -1.05  0.3  -2.28]	 Fitness: 26.82
# Individual 3: [ 4.22  0.33 -4.76  5.  ]	 Fitness: 23.47
# Individual 4: [-5.   1.7 -5.  -5. ]	 Fitness: 100.00
# Individual 5: [ 2.29 -1.59  5.   -0.07]	 Fitness: 11.74
#
#  =================================================================
#
# Iteration 931:
# ---------------
# Individual 1: [-4.55  0.07 -0.26 -0.1 ]	 Fitness: 20.75
# Individual 2: [-2.45 -1.05  0.3  -2.28]	 Fitness: 12.38
# Individual 3: [ 4.22  0.33 -4.76  5.  ]	 Fitness: 65.60
# Individual 4: [-5.   1.7 -5.  -5. ]	 Fitness: 77.89
# Individual 5: [ 2.29 -1.59  5.   -0.07]	 Fitness: 32.79
# -----------------------------------------------------------------
# Teacher: [-2.45 -1.05  0.3  -2.28]	 Fitness: 12.38
# -----------------------------------------------------------------
# Population Mean: [-1.1  -0.11 -0.94 -0.49]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-4.76 -0.41  1.59 -1.39]	 Fitness: 20.75
# Individual 2: [-2.69 -1.6   0.83 -2.62]	 Fitness: 12.38
# Individual 3: [ 4.07 -0.32 -2.62  3.73]	 Fitness: 65.60
# Individual 4: [-5.    1.37 -4.96 -5.  ]	 Fitness: 77.89
# Individual 5: [ 2.06 -1.78  5.   -0.87]	 Fitness: 32.79
# -----------------------------------------------------------------
# Partner: [ 4.07 -0.32 -2.62  3.73]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-4.76 -0.41  1.59 -1.39]	 Fitness: 20.75
# Individual 2: [-2.69 -1.6   0.83 -2.62]	 Fitness: 12.38
# Individual 3: [-4.87  1.34 -3.94 -0.61]	 Fitness: 65.60
# Individual 4: [-5.    3.37 -5.   -5.  ]	 Fitness: 77.89
# Individual 5: [ 4.88 -1.89  5.    0.72]	 Fitness: 32.79
#
#  =================================================================
#
# Iteration 932:
# ---------------
# Individual 1: [-4.76 -0.41  1.59 -1.39]	 Fitness: 27.23
# Individual 2: [-2.69 -1.6   0.83 -2.62]	 Fitness: 17.36
# Individual 3: [-4.87  1.34 -3.94 -0.61]	 Fitness: 41.38
# Individual 4: [-5.    3.37 -5.   -5.  ]	 Fitness: 86.38
# Individual 5: [ 4.88 -1.89  5.    0.72]	 Fitness: 52.89
# -----------------------------------------------------------------
# Teacher: [-2.69 -1.6   0.83 -2.62]	 Fitness: 17.36
# -----------------------------------------------------------------
# Population Mean: [-2.49  0.16 -0.31 -1.78]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-3.95 -2.21  2.82 -1.27]	 Fitness: 27.23
# Individual 2: [-2.05 -2.48  1.59 -2.04]	 Fitness: 17.36
# Individual 3: [-2.68 -0.57 -3.12 -0.13]	 Fitness: 41.38
# Individual 4: [-3.03  2.88 -4.38 -4.44]	 Fitness: 86.38
# Individual 5: [ 5.   -2.4   5.    0.97]	 Fitness: 52.89
# -----------------------------------------------------------------
# Partner: [-3.03  2.88 -4.38 -4.44]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-4.95 -2.21  3.03 -1.13]	 Fitness: 27.23
# Individual 2: [-2.47 -1.41  1.55 -0.62]	 Fitness: 17.36
# Individual 3: [-2.24  0.02 -3.39  0.14]	 Fitness: 41.38
# Individual 4: [-3.49  4.69 -5.   -5.  ]	 Fitness: 86.38
# Individual 5: [ 5.   -2.42  5.    1.28]	 Fitness: 52.89
#
#  =================================================================
#
# Iteration 933:
# ---------------
# Individual 1: [-4.95 -2.21  3.03 -1.13]	 Fitness: 39.80
# Individual 2: [-2.47 -1.41  1.55 -0.62]	 Fitness: 10.89
# Individual 3: [-2.24  0.02 -3.39  0.14]	 Fitness: 16.50
# Individual 4: [-3.49  4.69 -5.   -5.  ]	 Fitness: 84.18
# Individual 5: [ 5.   -2.42  5.    1.28]	 Fitness: 57.49
# -----------------------------------------------------------------
# Teacher: [-2.47 -1.41  1.55 -0.62]	 Fitness: 10.89
# -----------------------------------------------------------------
# Population Mean: [-1.63 -0.27  0.24 -1.07]
# -----------------------------------------------------------------
# [1] The Population After Teaching Phase:
# ----------------------------------------
# Individual 1: [-4.74 -2.27  3.64 -0.76]	 Fitness: 39.80
# Individual 2: [-2.2  -1.75  1.57  0.69]	 Fitness: 10.89
# Individual 3: [-2.   -0.64 -3.37  0.79]	 Fitness: 16.50
# Individual 4: [-3.11  3.97 -4.36 -3.66]	 Fitness: 84.18
# Individual 5: [ 5.   -3.03  5.    1.86]	 Fitness: 57.49
# -----------------------------------------------------------------
# Partner: [-4.74 -2.27  3.64 -0.76]
# -----------------------------------------------------------------
# [2] The Population After Learning Phase:
# ----------------------------------------
# Individual 1: [-5.   -2.41  5.   -0.97]	 Fitness: 39.80
# Individual 2: [-2.09 -1.52 -1.92  0.73]	 Fitness: 10.89
# Individual 3: [-3.82 -1.4  -0.11  0.09]	 Fitness: 16.50
# Individual 4: [-4.44  5.   -5.   -5.  ]	 Fitness: 84.18
# Individual 5: [ 5.   -4.03  5.    2.17]	 Fitness: 57.49
#
#  =================================================================
#
# Minimum Solution: [-2.09 -1.52 -1.92  0.73]	 Fitness: 10.89
#
#  =================================================================

# %% [markdown]
# #6 - Conclusion

# %% [markdown]
# The Teaching-Learning-Based Optimization (TLBO) algorithm presents a promising approach to optimization tasks. Its simplicity and effectiveness make it suitable for various problem domains. While further research may enhance its performance, TLBO stands as a valuable tool for tackling optimization challenges.
